# %% [markdown]
# We are starting from the fragment-based mapping step to obtain matrix containing inversion event

# %%
from pytadbit.mapping.full_mapper import full_mapping
import pytadbit
# Out:
# IMP not found, check PYTHONPATH
# /home/nikita/miniconda2/lib/python2.7/site-packages/pytadbit/__init__.py:126: UserWarning: IMP not found, check PYTHONPATH
#
#   warn('IMP not found, check PYTHONPATH\n')

# %%
r_enz = 'BglII'
rep = '1'

# %%
print 'Mapping the first end of the read\n'
mapped_r1 = full_mapping(gem_index_path='/home/nikita/Projects/Chromosomal_aberrations/data/genome/Caulobacter_crescentus/Caulobacter_inversion.gem',
                         fastq_path='/home/nikita/Projects/Chromosomal_aberrations/data/FASTQs/LaublabBglII_HiC_NA1000_swarmer_cell_untreated_replicate1.fastq',
                         out_map_dir='/home/nikita/Projects/Chromosomal_aberrations/results_inv/Caulobacter_BglII_replicate1_inv/01mapping/Caulobacter_BglII_replicate1_mapped_r1_inv',
                         windows=(1, 40),
                         r_enz='BglII', frag_map=True, nthreads=4, clean=True, 
                         temp_dir='/home/nikita/Projects/Chromosomal_aberrations/results_inv/Caulobacter_BglII_replicate1_inv/01mapping/Caulobacter_BglII_replicate1_mapped_r1_tmp_inv')
# Out:
# Mapping the first end of the read
#
# Preparing FASTQ file
#   - conversion to MAP format
#   - trimming reads 1-40
# Mapping reads in window 1-40...
# TO GEM /home/nikita/Projects/Chromosomal_aberrations/results_inv/Caulobacter_BglII_replicate1_inv/01mapping/Caulobacter_BglII_replicate1_mapped_r1_tmp_inv/LaublabBglII_HiC_NA1000_swarmer_cell_untreated_replicate1_z7_u3A
# ...

# %%
print 'n\nMapping the second end of the read\n'
mapped_r2 = full_mapping(gem_index_path='/home/nikita/Projects/Chromosomal_aberrations/data/genome/Caulobacter_crescentus/Caulobacter_inversion.gem',
                         fastq_path='/home/nikita/Projects/Chromosomal_aberrations/data/FASTQs/LaublabBglII_HiC_NA1000_swarmer_cell_untreated_replicate1.fastq',
                         out_map_dir='/home/nikita/Projects/Chromosomal_aberrations/results_inv/Caulobacter_BglII_replicate1_inv/01mapping/Caulobacter_BglII_replicate1_mapped_r2_inv',
                         windows=(41, 80),
                         r_enz='BglII', frag_map=True, nthreads=4, clean=False, 
                         temp_dir='/home/nikita/Projects/Chromosomal_aberrations/results_inv/Caulobacter_BglII_replicate1_inv/01mapping/Caulobacter_BglII_replicate1_mapped_r2_tmp_inv')
# Out:
# n
# Mapping the second end of the read
#
# Preparing FASTQ file
#   - conversion to MAP format
#   - trimming reads 41-80
# Mapping reads in window 41-80...
# TO GEM /home/nikita/Projects/Chromosomal_aberrations/results_inv/Caulobacter_BglII_replicate1_inv/01mapping/Caulobacter_BglII_replicate1_mapped_r2_tmp_inv/LaublabBglII_HiC_NA1000_swarmer_cell_untreated_replicate1_YfH_r0
# ...

# %%
from pytadbit.parsers.genome_parser import parse_fasta
from matplotlib import pyplot as plt
import numpy as np

# %%
genome_seq = parse_fasta('/home/nikita/Projects/Chromosomal_aberrations/data/genome/Caulobacter_crescentus/inversion.fa')
# Out:
# Parsing chr1

# %%
from pytadbit.mapping.restriction_enzymes import map_re_sites

frags_BglII = map_re_sites('BglII', genome_seq, verbose=True)
# Out:
# Found 700 RE sites

# %%
c0 = frags_BglII.keys()[0]
v0 = 0
dists_BglII = []
for c1, v1 in [(c, v) for c in frags_BglII for p in frags_BglII[c] 
               for v in frags_BglII[c][p]]:
    if c1 == c0:
        diff = abs(v1 - v0)
        if diff < 30000:
            dists_BglII.append(diff)
    v0 = v1
    
plt.figure(figsize=(12, 6))
_ = plt.hist([dists_BglII], bins=50, color=['red'], 
             alpha=0.5, label=['BglII'])
y0, y1 = plt.ylim()
plt.vlines(np.median(dists_BglII), y0, y1 * 0.7, color='red', linestyle='--',
          label='median BglII')
plt.text(np.median(dists_BglII), y1 * 0.7, '%.0f' % np.median(dists_BglII), va='bottom', 
         ha='left')
plt.title('Restriction fragment size distribution')
plt.legend()
plt.grid()

# %%
maps1 = ['/home/nikita/Projects/Chromosomal_aberrations/results_inv/Caulobacter_BglII_replicate1_inv/01mapping/Caulobacter_BglII_replicate1_mapped_r1_inv/LaublabBglII_HiC_NA1000_swarmer_cell_untreated_replicate1_full_1-40.map', '/home/nikita/Projects/Chromosomal_aberrations/results_inv/Caulobacter_BglII_replicate1_inv/01mapping/Caulobacter_BglII_replicate1_mapped_r1_inv/LaublabBglII_HiC_NA1000_swarmer_cell_untreated_replicate1_frag_1-40.map']

maps2 = ['/home/nikita/Projects/Chromosomal_aberrations/results_inv/Caulobacter_BglII_replicate1_inv/01mapping/Caulobacter_BglII_replicate1_mapped_r2_inv/LaublabBglII_HiC_NA1000_swarmer_cell_untreated_replicate1_full_41-80.map', '/home/nikita/Projects/Chromosomal_aberrations/results_inv/Caulobacter_BglII_replicate1_inv/01mapping/Caulobacter_BglII_replicate1_mapped_r2_inv/LaublabBglII_HiC_NA1000_swarmer_cell_untreated_replicate1_frag_41-80.map']

# %%
reads1 = '/home/nikita/Projects/Chromosomal_aberrations/results_inv/Caulobacter_BglII_replicate1_inv/02_parsing/reads1.tsv'
reads2 = '/home/nikita/Projects/Chromosomal_aberrations/results_inv/Caulobacter_BglII_replicate1_inv/02_parsing/reads2.tsv'

# %%
from pytadbit.parsers.map_parser import parse_map
print 'Parse MAP files....'
parse_map(maps1, maps2, out_file1=reads1, out_file2=reads2, genome_seq=genome_seq, 
          re_name='BglII', 
          verbose=True)
# Out:
# Parse MAP files....
# Searching and mapping RE sites to the reference genome
# Found 700 RE sites
# Loading read1
# loading file: /home/nikita/Projects/Chromosomal_aberrations/results_inv/Caulobacter_BglII_replicate1_inv/01mapping/Caulobacter_BglII_replicate1_mapped_r1_inv/LaublabBglII_HiC_NA1000_swarmer_cell_untreated_replicate1_full_1-40.map
# loading file: /home/nikita/Projects/Chromosomal_aberrations/results_inv/Caulobacter_BglII_replicate1_inv/01mapping/Caulobacter_BglII_replicate1_mapped_r1_inv/LaublabBglII_HiC_NA1000_swarmer_cell_untreated_replicate1_frag_1-40.map
# Merge sort.................
# Getting Multiple contacts
# Loading read2
# loading file: /home/nikita/Projects/Chromosomal_aberrations/results_inv/Caulobacter_BglII_replicate1_inv/01mapping/Caulobacter_BglII_replicate1_mapped_r2_inv/LaublabBglII_HiC_NA1000_swarmer_cell_untreated_replicate1_full_41-80.map
# ...

# %%
from pytadbit.mapping import get_intersection

# %%
reads ='/home/nikita/Projects/Chromosomal_aberrations/results_inv/Caulobacter_BglII_replicate1_inv/03_filtering/reads12.tsv'

# %%
get_intersection(reads1, reads2, reads, verbose=True)
# Out:
# Getting intersection of reads 1 and reads 2:
#
#   .......... .......
# Found 14689494 pair of reads mapping uniquely
# Sorting each temporary file by genomic coordinate
#     1025/1025 sorted files
# Removing temporary files...
# (14689494, {2: 375370, 3: 4})

# %%
from pytadbit.mapping.analyze import plot_distance_vs_interactions
plot_distance_vs_interactions(reads, resolution=100000, max_diff=40, show=True)
# Out:
# ((-1.0168223512107757, 10.770111034023852, -0.98862089118295038),
#  (-1.2277173117438736, 11.455646373645507, -0.76253516824262335),
#  (0, 0, 0))

# %%
from pytadbit.mapping.analyze import plot_genomic_distribution
plot_genomic_distribution(reads, resolution=50000,  show=True)

# %%
from pytadbit.mapping.analyze import hic_map
hic_map(reads, resolution=10000, show=True)
